# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

import keras
from keras.models import Sequential
from keras.layers import *
from keras.utils import np_utils
from tensorflow.keras.optimizers import SGD

from sklearn.model_selection import cross_val_score, KFold, train_test_split, GridSearchCV
from sklearn.metrics import accuracy_score
from sklearn.decomposition import PCA
from sklearn.preprocessing import OneHotEncoder
from scikeras.wrappers import KerasClassifier

from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, LearningRateScheduler, History

from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# %%
features_dr = 'C:/Users/norma/Desktop/BITIRME/GSE_OrtakData_NormR.csv'
labels_dr = 'C:/Users/norma/Desktop/BITIRME/gse_less_feature.csv'

features_df = pd.read_csv(features_dr, sep = ";")
labels_df = pd.read_csv(labels_dr, sep = ",", dtype='unicode')

features = features_df.drop('Class',axis=1)
labels = labels_df.iloc[:,:3]
labels_without_mci = labels_df.iloc[:,:2]

# %% [markdown]
# # **PCA**

# %% [markdown]
# ## n_components = 5

# %%
pca = PCA(n_components = 5).fit(features)
principalComponents = pca.fit_transform(features)
columns = ['Pc' + str(i) for i in range(1,6)]
principalDf = pd.DataFrame(data = principalComponents
             , columns = columns)

# %% [markdown]
# ## n_components = 114

# %%
features_df = pd.read_csv(features_dr, sep = ";")
features2 = features_df.drop('Class',axis=1)

pca2 = PCA(n_components = 114).fit(features)
principalComponents2 = pca2.fit_transform(features)
columns2 = ['Pc' + str(i) for i in range(1,115)]
principalDf2 = pd.DataFrame(data = principalComponents2
             , columns = columns2)

# %%
## MODEL

# %%
# Optimizer settings
epochs=60
learning_rate = 0.1
decay_rate = learning_rate / epochs
momentum = 0.8

sgd = SGD(learning_rate=learning_rate, momentum=momentum, decay=decay_rate, nesterov=False)

# %%
# repeat some of the initial values here so we make sure they were not changed
input_dim = 114

# let's create a function that creates the model (required for KerasClassifier) 
# while accepting the hyperparameters we want to tune 
# we also pass some default values such as optimizer='rmsprop'
def build_model(optimizer=sgd, init_mode='glorot_uniform'):
    model = Sequential()
    model.add(Dense(64, input_dim=input_dim, kernel_initializer=init_mode, activation='relu'))
    model.add(Dropout(0.1))
    model.add(Dense(64, kernel_initializer=init_mode, activation='relu'))
    model.add(Dropout(0.1))
    model.add(Dense(3, kernel_initializer=init_mode, activation='softmax'))

    # compile model
    model.compile(loss='categorical_crossentropy', 
                  optimizer=optimizer, 
                  metrics=['accuracy'])

    return model

# %% [markdown]
# ## Train test split with and without MCI class

# %%
x_train_n114_w, x_test_n114_w, y_train_n114_w, y_test_n114_w = train_test_split(principalDf2, labels, test_size= 0.2, random_state=42)
y_train_n114_w = y_train_n114_w.astype(int)
y_test_n114_w = y_test_n114_w.astype(int)

# %%
ckpt = keras.callbacks.ModelCheckpoint(
        filepath='C:/Users/norma/Desktop/BITIRME/Models/MLP/best_model_114w.{epoch:02d}-{accuracy:.4f}.h5',
        monitor='accuracy', save_best_only=True,verbose=1)

callbacks = [EarlyStopping(monitor='accuracy', patience=30, mode='min', min_delta=0.0001),
         ckpt]

model_n114w = build_model()

# %%
history114w = model_n114w.fit(
          x = np.asarray(x_train_n114_w).astype('float32'),
          y = y_train_n114_w,
          steps_per_epoch=len(principalDf2)//32,
          epochs=50,
          callbacks=[callbacks]
          )
model_n114w.save("finishModel.h5")
# Out:
# Epoch 1/50
# 37/39 [===========================>..] - ETA: 0s - loss: 1.0917 - accuracy: 0.3805
# Epoch 1: accuracy improved from -inf to 0.37760, saving model to C:/Users/norma/Desktop/BITIRME/Models/MLP\best_model_114w.01-0.3776.h5
# 39/39 [==============================] - 0s 2ms/step - loss: 1.0926 - accuracy: 0.3776
# Epoch 2/50
#  1/39 [..............................] - ETA: 0s - loss: 1.1697 - accuracy: 0.3077
# Epoch 2: accuracy improved from 0.37760 to 0.40139, saving model to C:/Users/norma/Desktop/BITIRME/Models/MLP\best_model_114w.02-0.4014.h5
# 39/39 [==============================] - 0s 2ms/step - loss: 1.0782 - accuracy: 0.4014
# Epoch 3/50
#  1/39 [..............................] - ETA: 0s - loss: 1.0898 - accuracy: 0.4231
# Epoch 3: accuracy improved from 0.40139 to 0.41031, saving model to C:/Users/norma/Desktop/BITIRME/Models/MLP\best_model_114w.03-0.4103.h5
# 39/39 [==============================] - 0s 2ms/step - loss: 1.0800 - accuracy: 0.4103
# Epoch 4/50
#  1/39 [..............................] - ETA: 0s - loss: 1.0670 - accuracy: 0.5000
# Epoch 4: accuracy improved from 0.41031 to 0.42616, saving model to C:/Users/norma/Desktop/BITIRME/Models/MLP\best_model_114w.04-0.4262.h5
# 39/39 [==============================] - 0s 2ms/step - loss: 1.0688 - accuracy: 0.4262
# Epoch 5/50
# 39/39 [==============================] - ETA: 0s - loss: 1.0679 - accuracy: 0.4192
# Epoch 5: accuracy did not improve from 0.42616
# 39/39 [==============================] - 0s 1ms/step - loss: 1.0679 - accuracy: 0.4192
# Epoch 6/50
# 37/39 [===========================>..] - ETA: 0s - loss: 1.0560 - accuracy: 0.4636
# Epoch 6: accuracy improved from 0.42616 to 0.46184, saving model to C:/Users/norma/Desktop/BITIRME/Models/MLP\best_model_114w.06-0.4618.h5
# 39/39 [==============================] - 0s 2ms/step - loss: 1.0561 - accuracy: 0.4618
# Epoch 7/50
#  1/39 [..............................] - ETA: 0s - loss: 1.0098 - accuracy: 0.5769
# Epoch 7: accuracy did not improve from 0.46184
# 39/39 [==============================] - 0s 1ms/step - loss: 1.0541 - accuracy: 0.4400
# Epoch 8/50
#  1/39 [..............................] - ETA: 0s - loss: 1.0311 - accuracy: 0.4615
# Epoch 8: accuracy did not improve from 0.46184
# 39/39 [==============================] - 0s 1ms/step - loss: 1.0547 - accuracy: 0.4450
# Epoch 9/50
#  1/39 [..............................] - ETA: 0s - loss: 0.9764 - accuracy: 0.6154
# Epoch 9: accuracy did not improve from 0.46184
# 39/39 [==============================] - 0s 1ms/step - loss: 1.0492 - accuracy: 0.4361
# Epoch 10/50
#  1/39 [..............................] - ETA: 0s - loss: 1.0288 - accuracy: 0.3462
# Epoch 10: accuracy did not improve from 0.46184
# 39/39 [==============================] - 0s 1ms/step - loss: 1.0386 - accuracy: 0.4609
# Epoch 11/50
#  1/39 [..............................] - ETA: 0s - loss: 1.0192 - accuracy: 0.5769
# Epoch 11: accuracy did not improve from 0.46184
# 39/39 [==============================] - 0s 1ms/step - loss: 1.0365 - accuracy: 0.4549
# Epoch 12/50
# 31/39 [======================>.......] - ETA: 0s - loss: 1.0337 - accuracy: 0.4752
# Epoch 12: accuracy improved from 0.46184 to 0.46482, saving model to C:/Users/norma/Desktop/BITIRME/Models/MLP\best_model_114w.12-0.4648.h5
# 39/39 [==============================] - 0s 2ms/step - loss: 1.0358 - accuracy: 0.4648
# Epoch 13/50
# 34/39 [=========================>....] - ETA: 0s - loss: 1.0313 - accuracy: 0.4638
# Epoch 13: accuracy did not improve from 0.46482
# 39/39 [==============================] - 0s 2ms/step - loss: 1.0392 - accuracy: 0.4559
# Epoch 14/50
# 38/39 [============================>.] - ETA: 0s - loss: 1.0324 - accuracy: 0.4565
# Epoch 14: accuracy did not improve from 0.46482
# 39/39 [==============================] - 0s 1ms/step - loss: 1.0322 - accuracy: 0.4579
# Epoch 15/50
#  1/39 [..............................] - ETA: 0s - loss: 0.9310 - accuracy: 0.5385
# Epoch 15: accuracy improved from 0.46482 to 0.48464, saving model to C:/Users/norma/Desktop/BITIRME/Models/MLP\best_model_114w.15-0.4846.h5
# 39/39 [==============================] - 0s 2ms/step - loss: 1.0188 - accuracy: 0.4846
# Epoch 16/50
#  1/39 [..............................] - ETA: 0s - loss: 0.9966 - accuracy: 0.5769
# Epoch 16: accuracy did not improve from 0.48464
# 39/39 [==============================] - 0s 1ms/step - loss: 1.0312 - accuracy: 0.4727
# Epoch 17/50
#  1/39 [..............................] - ETA: 0s - loss: 0.9073 - accuracy: 0.5385
# Epoch 17: accuracy did not improve from 0.48464
# 39/39 [==============================] - 0s 1ms/step - loss: 1.0248 - accuracy: 0.4688
# Epoch 18/50
# 38/39 [============================>.] - ETA: 0s - loss: 1.0128 - accuracy: 0.4838
# Epoch 18: accuracy did not improve from 0.48464
# 39/39 [==============================] - 0s 1ms/step - loss: 1.0144 - accuracy: 0.4807
# Epoch 19/50
# 27/39 [===================>..........] - ETA: 0s - loss: 1.0191 - accuracy: 0.4715
# Epoch 19: accuracy did not improve from 0.48464
# 39/39 [==============================] - 0s 2ms/step - loss: 1.0087 - accuracy: 0.4817
# Epoch 20/50
# 25/39 [==================>...........] - ETA: 0s - loss: 1.0284 - accuracy: 0.4738
# Epoch 20: accuracy improved from 0.48464 to 0.48761, saving model to C:/Users/norma/Desktop/BITIRME/Models/MLP\best_model_114w.20-0.4876.h5
# 39/39 [==============================] - 0s 3ms/step - loss: 1.0148 - accuracy: 0.4876
# Epoch 21/50
#  1/39 [..............................] - ETA: 0s - loss: 1.0784 - accuracy: 0.4231
# Epoch 21: accuracy improved from 0.48761 to 0.49950, saving model to C:/Users/norma/Desktop/BITIRME/Models/MLP\best_model_114w.21-0.4995.h5
# 39/39 [==============================] - 0s 2ms/step - loss: 1.0089 - accuracy: 0.4995
# Epoch 22/50
#  1/39 [..............................] - ETA: 0s - loss: 0.9822 - accuracy: 0.5385
# Epoch 22: accuracy did not improve from 0.49950
# 39/39 [==============================] - 0s 1ms/step - loss: 1.0058 - accuracy: 0.4836
# Epoch 23/50
#  1/39 [..............................] - ETA: 0s - loss: 1.0078 - accuracy: 0.4615
# Epoch 23: accuracy did not improve from 0.49950
# 39/39 [==============================] - 0s 1ms/step - loss: 1.0091 - accuracy: 0.4886
# Epoch 24/50
# 35/39 [=========================>....] - ETA: 0s - loss: 1.0032 - accuracy: 0.5077
# Epoch 24: accuracy improved from 0.49950 to 0.51338, saving model to C:/Users/norma/Desktop/BITIRME/Models/MLP\best_model_114w.24-0.5134.h5
# 39/39 [==============================] - 0s 2ms/step - loss: 1.0014 - accuracy: 0.5134
# Epoch 25/50
# 39/39 [==============================] - ETA: 0s - loss: 1.0032 - accuracy: 0.4846
# Epoch 25: accuracy did not improve from 0.51338
# 39/39 [==============================] - 0s 1ms/step - loss: 1.0032 - accuracy: 0.4846
# Epoch 26/50
# 39/39 [==============================] - ETA: 0s - loss: 1.0036 - accuracy: 0.4975
# Epoch 26: accuracy did not improve from 0.51338
# 39/39 [==============================] - 0s 1ms/step - loss: 1.0036 - accuracy: 0.4975
# Epoch 27/50
#  7/39 [====>.........................] - ETA: 0s - loss: 1.0101 - accuracy: 0.5055
# Epoch 27: accuracy did not improve from 0.51338
# 39/39 [==============================] - 0s 2ms/step - loss: 1.0043 - accuracy: 0.4856
# Epoch 28/50
#  1/39 [..............................] - ETA: 0s - loss: 1.0708 - accuracy: 0.5000
# Epoch 28: accuracy did not improve from 0.51338
# 39/39 [==============================] - 0s 1ms/step - loss: 0.9941 - accuracy: 0.5084
# Epoch 29/50
#  1/39 [..............................] - ETA: 0s - loss: 0.8830 - accuracy: 0.6923
# Epoch 29: accuracy improved from 0.51338 to 0.51536, saving model to C:/Users/norma/Desktop/BITIRME/Models/MLP\best_model_114w.29-0.5154.h5
# 39/39 [==============================] - 0s 2ms/step - loss: 0.9924 - accuracy: 0.5154
# Epoch 30/50
#  1/39 [..............................] - ETA: 0s - loss: 0.9674 - accuracy: 0.5385
# Epoch 30: accuracy did not improve from 0.51536
# 39/39 [==============================] - 0s 1ms/step - loss: 0.9992 - accuracy: 0.5064
# Epoch 31/50
#  1/39 [..............................] - ETA: 0s - loss: 1.0167 - accuracy: 0.5385
# Epoch 31: accuracy did not improve from 0.51536
# 39/39 [==============================] - 0s 1ms/step - loss: 0.9841 - accuracy: 0.4985

# %%
y_pred_n114w = model_n114w.predict(x_test_n114_w)
y_pred_n114w = np.argmax(y_pred_n114w, axis=1)

class_d = 'C:/Users/norma/Desktop/BITIRME/GSE_OrtakData_NormR.csv'
class_df = pd.read_csv(class_d, sep = ';')
#creating instance of one-hot-encoder
encoder = OneHotEncoder(handle_unknown='ignore')

#perform one-hot encoding on 'team' column 
encoder_df = pd.DataFrame(encoder.fit_transform(class_df[['Class']]).toarray())
encoder_df.columns = ['AD','CTL','MCI']

y_test_n114_ = encoder.inverse_transform(y_test_n114_w).ravel()
y_test_n114_w = []
for i in y_test_n114_:
    if i == 'MCI':
        y_test_n114_w.append(2)
    elif i == 'AD':
        y_test_n114_w.append(0)
    elif i == 'CTL':
        y_test_n114_w.append(1)

# %%
print(accuracy_score(y_test_n114_w,y_pred_n114w))
# Out:
# 0.4782608695652174

# %%
# confusion matrix
matrix = confusion_matrix(y_test_n114_w,y_pred_n114w, labels=[2,1,0])
print('Confusion matrix : \n',matrix)

# outcome values order in sklearn
tp, fn, fp, tn = confusion_matrix(y_test_n114_w,y_pred_n114w,labels=[2,1,0]).reshape(-1)
print('Outcome values : \n', tp, fn, fp, tn)

# classification report for precision, recall f1-score and accuracy
matrix = classification_report(y_test_n114_w,y_pred_n114w,labels=[1,0])
print('Classification report : \n',matrix)
# Out:
# Confusion matrix :
#  [[ 1 36 26]
#  [ 2 58 28]
#  [ 1 39 62]]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6872/1693804107.py in <module>
#       4
#       5 # outcome values order in sklearn
# ----> 6 tp, fn, fp, tn = confusion_matrix(y_test_n114_w,y_pred_n114w,labels=[2,1,0]).reshape(-1)
#       7 print('Outcome values : \n', tp, fn, fp, tn)
#       8
#
# ValueError: too many values to unpack (expected 4)

# %%
### WITHOUT MCI

# %%
# x_train_n5w, x_test_n5w, y_train_n5w, y_test_n5w = train_test_split(principalDf, labels, test_size= 0.2, random_state=42)
# x_train_n5, x_test_n5, y_train_n5, y_test_n5 = train_test_split(principalDf, labels_without_mci, test_size= 0.2, random_state=42)
x_train_n114, x_test_n114, y_train_n114, y_test_n114 = train_test_split(principalDf2, labels_without_mci, test_size= 0.2, random_state=42)

# %%
y_train_n114 = y_train_n114.astype(int)
y_test_n114 = y_test_n114.astype(int)

# %%
# repeat some of the initial values here so we make sure they were not changed
input_dim = 114

# let's create a function that creates the model (required for KerasClassifier) 
# while accepting the hyperparameters we want to tune 
# we also pass some default values such as optimizer='rmsprop'
def build_model_2(optimizer=sgd, init_mode='glorot_uniform'):
    model = Sequential()
    model.add(Dense(64, input_dim=input_dim, kernel_initializer=init_mode, activation='relu'))
    model.add(Dropout(0.1))
    model.add(Dense(64, kernel_initializer=init_mode, activation='relu'))
    model.add(Dropout(0.1))
    model.add(Dense(2, kernel_initializer=init_mode, activation='softmax'))

    # compile model
    model.compile(loss='categorical_crossentropy', 
                  optimizer=optimizer, 
                  metrics=['accuracy'])

    return model

# %%
ckpt = keras.callbacks.ModelCheckpoint(
        filepath='C:/Users/norma/Desktop/BITIRME/Models/MLP/best_model_114.{epoch:02d}-{accuracy:.4f}.h5',
        monitor='accuracy', save_best_only=True,verbose=1)

callbacks = [EarlyStopping(monitor='accuracy', patience=30, mode='min', min_delta=0.0001),
         ckpt]

model_n114 = build_model_2()

# %%
history114 = model_n114.fit(
          x = np.asarray(x_train_n114).astype('float32'),
          y = y_train_n114,
          steps_per_epoch=len(principalDf2)//32,
          epochs=50,
          callbacks=[callbacks]
          )
model_n114.save("finishModel.h5")
# Out:
# Epoch 1/50
#  1/39 [..............................] - ETA: 11s - loss: 0.5449 - accuracy: 0.3077
# Epoch 1: accuracy improved from -inf to 0.49653, saving model to C:/Users/norma/Desktop/BITIRME/Models/MLP\best_model_114.01-0.4965.h5
# 39/39 [==============================] - 0s 2ms/step - loss: 0.5253 - accuracy: 0.4965
# Epoch 2/50
#  1/39 [..............................] - ETA: 0s - loss: 0.4568 - accuracy: 0.3846
# Epoch 2: accuracy improved from 0.49653 to 0.49851, saving model to C:/Users/norma/Desktop/BITIRME/Models/MLP\best_model_114.02-0.4985.h5
# 39/39 [==============================] - 0s 2ms/step - loss: 0.5268 - accuracy: 0.4985
# Epoch 3/50
#  1/39 [..............................] - ETA: 0s - loss: 0.4595 - accuracy: 0.7692
# Epoch 3: accuracy improved from 0.49851 to 0.51140, saving model to C:/Users/norma/Desktop/BITIRME/Models/MLP\best_model_114.03-0.5114.h5
# 39/39 [==============================] - 0s 2ms/step - loss: 31.2162 - accuracy: 0.5114
# Epoch 4/50
#  1/39 [..............................] - ETA: 0s - loss: 1557.4188 - accuracy: 0.5000
# Epoch 4: accuracy improved from 0.51140 to 0.55897, saving model to C:/Users/norma/Desktop/BITIRME/Models/MLP\best_model_114.04-0.5590.h5
# 39/39 [==============================] - 0s 2ms/step - loss: 272442.1562 - accuracy: 0.5590
# Epoch 5/50
#  1/39 [..............................] - ETA: 0s - loss: 0.5991 - accuracy: 0.5000
# Epoch 5: accuracy improved from 0.55897 to 0.62537, saving model to C:/Users/norma/Desktop/BITIRME/Models/MLP\best_model_114.05-0.6254.h5
# 39/39 [==============================] - 0s 2ms/step - loss: 0.5216 - accuracy: 0.6254
# Epoch 6/50
#  1/39 [..............................] - ETA: 0s - loss: 0.5061 - accuracy: 0.6538
# Epoch 6: accuracy did not improve from 0.62537
# 39/39 [==============================] - 0s 1ms/step - loss: 0.5217 - accuracy: 0.6234
# Epoch 7/50
#  1/39 [..............................] - ETA: 0s - loss: 0.5879 - accuracy: 0.5000
# Epoch 7: accuracy did not improve from 0.62537
# 39/39 [==============================] - 0s 1ms/step - loss: 0.5216 - accuracy: 0.5104
# Epoch 8/50
#  1/39 [..............................] - ETA: 0s - loss: 0.5273 - accuracy: 0.7692
# Epoch 8: accuracy did not improve from 0.62537
# 39/39 [==============================] - 0s 1ms/step - loss: 13.8908 - accuracy: 0.4737
# Epoch 9/50
#  1/39 [..............................] - ETA: 0s - loss: 0.6125 - accuracy: 0.6154
# Epoch 9: accuracy did not improve from 0.62537
# 39/39 [==============================] - 0s 1ms/step - loss: 0.5217 - accuracy: 0.6244
# Epoch 10/50
#  1/39 [..............................] - ETA: 0s - loss: 0.5862 - accuracy: 0.5000
# Epoch 10: accuracy did not improve from 0.62537
# 39/39 [==============================] - 0s 1ms/step - loss: 0.5215 - accuracy: 0.3756
# Epoch 11/50
#  1/39 [..............................] - ETA: 0s - loss: 0.4536 - accuracy: 0.2692
# Epoch 11: accuracy did not improve from 0.62537
# 39/39 [==============================] - 0s 1ms/step - loss: 0.5215 - accuracy: 0.6125
# Epoch 12/50
# 36/39 [==========================>...] - ETA: 0s - loss: 0.5194 - accuracy: 0.5513
# Epoch 12: accuracy did not improve from 0.62537
# 39/39 [==============================] - 0s 2ms/step - loss: 0.5218 - accuracy: 0.5342
# Epoch 13/50
# 31/39 [======================>.......] - ETA: 0s - loss: 0.5271 - accuracy: 0.4516
# Epoch 13: accuracy did not improve from 0.62537
# 39/39 [==============================] - 0s 2ms/step - loss: 0.5221 - accuracy: 0.4836
# Epoch 14/50
#  1/39 [..............................] - ETA: 0s - loss: 0.5069 - accuracy: 0.6154
# Epoch 14: accuracy did not improve from 0.62537
# 39/39 [==============================] - 0s 1ms/step - loss: 0.5215 - accuracy: 0.5580
# Epoch 15/50
#  1/39 [..............................] - ETA: 0s - loss: 0.5600 - accuracy: 0.3846
# Epoch 15: accuracy did not improve from 0.62537
# 39/39 [==============================] - 0s 1ms/step - loss: 0.5228 - accuracy: 0.4113
# Epoch 16/50
# 36/39 [==========================>...] - ETA: 0s - loss: 0.5246 - accuracy: 0.6239
# Epoch 16: accuracy did not improve from 0.62537
# 39/39 [==============================] - 0s 1ms/step - loss: 0.5224 - accuracy: 0.6234
# Epoch 17/50
#  1/39 [..............................] - ETA: 0s - loss: 0.5865 - accuracy: 0.5769
# Epoch 17: accuracy did not improve from 0.62537
# 39/39 [==============================] - 0s 1ms/step - loss: 0.5222 - accuracy: 0.5154
# Epoch 18/50
# 39/39 [==============================] - ETA: 0s - loss: 0.5216 - accuracy: 0.4936
# Epoch 18: accuracy did not improve from 0.62537
# 39/39 [==============================] - 0s 1ms/step - loss: 0.5216 - accuracy: 0.4936
# Epoch 19/50
# 31/39 [======================>.......] - ETA: 0s - loss: 0.5222 - accuracy: 0.4690
# Epoch 19: accuracy did not improve from 0.62537
# 39/39 [==============================] - 0s 2ms/step - loss: 0.5217 - accuracy: 0.4430
# Epoch 20/50
# 22/39 [===============>..............] - ETA: 0s - loss: 0.5101 - accuracy: 0.5105
# Epoch 20: accuracy did not improve from 0.62537
# 39/39 [==============================] - 0s 2ms/step - loss: 0.5256 - accuracy: 0.5461
# Epoch 21/50
# 35/39 [=========================>....] - ETA: 0s - loss: 0.5144 - accuracy: 0.5714
# Epoch 21: accuracy did not improve from 0.62537
# 39/39 [==============================] - 0s 1ms/step - loss: 0.5216 - accuracy: 0.5560
# Epoch 22/50
#  1/39 [..............................] - ETA: 0s - loss: 0.5064 - accuracy: 0.3846
# Epoch 22: accuracy did not improve from 0.62537
# 39/39 [==============================] - 0s 1ms/step - loss: 0.5218 - accuracy: 0.5074
# Epoch 23/50
#  1/39 [..............................] - ETA: 0s - loss: 0.4266 - accuracy: 0.3077
# Epoch 23: accuracy did not improve from 0.62537
# 39/39 [==============================] - 0s 1ms/step - loss: 0.5220 - accuracy: 0.4569
# Epoch 24/50
#  1/39 [..............................] - ETA: 0s - loss: 0.5856 - accuracy: 0.4615
# Epoch 24: accuracy did not improve from 0.62537
# 39/39 [==============================] - 0s 1ms/step - loss: 0.5223 - accuracy: 0.5124
# Epoch 25/50
# 39/39 [==============================] - ETA: 0s - loss: 0.5217 - accuracy: 0.5342
# Epoch 25: accuracy did not improve from 0.62537
# 39/39 [==============================] - 0s 1ms/step - loss: 0.5217 - accuracy: 0.5342
# Epoch 26/50
#  1/39 [..............................] - ETA: 0s - loss: 0.5600 - accuracy: 0.3846
# Epoch 26: accuracy did not improve from 0.62537
# 39/39 [==============================] - 0s 1ms/step - loss: 0.5216 - accuracy: 0.4341
# Epoch 27/50
#  1/39 [..............................] - ETA: 0s - loss: 0.4799 - accuracy: 0.6538
# Epoch 27: accuracy did not improve from 0.62537
# 39/39 [==============================] - 0s 1ms/step - loss: 0.5217 - accuracy: 0.4192
# Epoch 28/50
# 39/39 [==============================] - ETA: 0s - loss: 0.5215 - accuracy: 0.6145
# Epoch 28: accuracy did not improve from 0.62537
# 39/39 [==============================] - 0s 1ms/step - loss: 0.5215 - accuracy: 0.6145
# Epoch 29/50
#  1/39 [..............................] - ETA: 0s - loss: 0.5097 - accuracy: 0.4615
# Epoch 29: accuracy did not improve from 0.62537
# 39/39 [==============================] - 0s 1ms/step - loss: 2.7686 - accuracy: 0.4737
# Epoch 30/50
#  1/39 [..............................] - ETA: 0s - loss: 0.4266 - accuracy: 0.6923
# Epoch 30: accuracy did not improve from 0.62537
# 39/39 [==============================] - 0s 1ms/step - loss: 0.5216 - accuracy: 0.6244
# Epoch 31/50
#  1/39 [..............................] - ETA: 0s - loss: 0.4262 - accuracy: 0.7692
# Epoch 31: accuracy did not improve from 0.62537
# 39/39 [==============================] - 0s 1ms/step - loss: 0.5216 - accuracy: 0.5203
# Epoch 32/50
#  1/39 [..............................] - ETA: 0s - loss: 0.5584 - accuracy: 0.4615
# Epoch 32: accuracy did not improve from 0.62537
# 39/39 [==============================] - 0s 1ms/step - loss: 0.5216 - accuracy: 0.3776
# Epoch 33/50
# 31/39 [======================>.......] - ETA: 0s - loss: 0.5226 - accuracy: 0.5124
# Epoch 33: accuracy did not improve from 0.62537
# 39/39 [==============================] - 0s 2ms/step - loss: 0.5219 - accuracy: 0.5193
# Epoch 34/50
#  1/39 [..............................] - ETA: 0s - loss: 0.4530 - accuracy: 0.7308
# Epoch 34: accuracy did not improve from 0.62537
# 39/39 [==============================] - 0s 1ms/step - loss: 0.5216 - accuracy: 0.4123
# Epoch 35/50
#  1/39 [..............................] - ETA: 0s - loss: 0.5594 - accuracy: 0.7692
# Epoch 35: accuracy did not improve from 0.62537
# 39/39 [==============================] - 0s 1ms/step - loss: 0.5216 - accuracy: 0.5322
# Epoch 36/50
#  1/39 [..............................] - ETA: 0s - loss: 0.4266 - accuracy: 0.6923
# Epoch 36: accuracy did not improve from 0.62537
# 39/39 [==============================] - 0s 1ms/step - loss: 0.5215 - accuracy: 0.4321
# Epoch 37/50
#  1/39 [..............................] - ETA: 0s - loss: 0.4266 - accuracy: 0.6923
# Epoch 37: accuracy did not improve from 0.62537
# 39/39 [==============================] - 0s 1ms/step - loss: 0.5219 - accuracy: 0.5193
# Epoch 38/50
#  1/39 [..............................] - ETA: 0s - loss: 0.5623 - accuracy: 0.4615
# Epoch 38: accuracy did not improve from 0.62537
# 39/39 [==============================] - 0s 1ms/step - loss: 0.5218 - accuracy: 0.4361
# Epoch 39/50
# 39/39 [==============================] - ETA: 0s - loss: 0.5216 - accuracy: 0.6244
# Epoch 39: accuracy did not improve from 0.62537
# 39/39 [==============================] - 0s 1ms/step - loss: 0.5216 - accuracy: 0.6244
# Epoch 40/50
#  1/39 [..............................] - ETA: 0s - loss: 0.6134 - accuracy: 0.5385
# Epoch 40: accuracy did not improve from 0.62537
# 39/39 [==============================] - 0s 1ms/step - loss: 0.5217 - accuracy: 0.4232

# %%
y_pred_n114 = model_n114.predict(x_test_n114)
y_pred_n114 = np.argmax(y_pred_n114, axis=1)

class_d = 'C:/Users/norma/Desktop/BITIRME/GSE_OrtakData_NormR.csv'
class_df = pd.read_csv(class_d, sep = ';')
#creating instance of one-hot-encoder
encoder = OneHotEncoder(handle_unknown='ignore')

#perform one-hot encoding on 'team' column 
encoder_df = pd.DataFrame(encoder.fit_transform(class_df[['Class']]).toarray())
encoder_df = encoder_df.iloc[:,:2]
encoder_df.columns = ['AD','CTL']

y_test_n114 = encoder.inverse_transform(y_test_n114).ravel()
y_test_n114_ = []

for i in y_test_n114:
    if i == 'AD':
        y_test_n114_.append(0)
    elif i == 'CTL':
        y_test_n114_.append(1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6872/1219498315.py in <module>
#      12 encoder_df.columns = ['AD','CTL']
#      13
# ---> 14 y_test_n114 = encoder.inverse_transform(y_test_n114).ravel()
#      15 y_test_n114_ = []
#      16
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py in inverse_transform(self, X)
#     597         )
#     598         if X.shape[1] != n_transformed_features:
# --> 599             raise ValueError(msg.format(n_transformed_features, X.shape[1]))
#     600
#     601         # create resulting array of appropriate dtype
#
# ValueError: Shape of the passed X data is not correct. Expected 3 columns, got 2.

# %%
# confusion matrix
matrix = confusion_matrix(y_test_n114_w,y_pred_n114w, labels=[2,1,0])
print('Confusion matrix : \n',matrix)

# outcome values order in sklearn
tp, fn, fp, tn = confusion_matrix(y_test_n114_w,y_pred_n114w,labels=[2,1,0]).reshape(-1)
print('Outcome values : \n', tp, fn, fp, tn)

# classification report for precision, recall f1-score and accuracy
matrix = classification_report(y_test_n114_w,y_pred_n114w,labels=[1,0])
print('Classification report : \n',matrix)
